# %%
dbutils.widgets.removeAll()

# %%
dbutils.widgets.text("storageName", "adlaiza082026")
dbutils.widgets.text("catalogo", "catalog_au")

# %%
storageName = dbutils.widgets.get("storageName")
catalogo = dbutils.widgets.get("catalogo")

# %% [markdown]
# ELIMINACIÓN TABLAS BRONCE

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.bronze.goodreads_books;
DROP TABLE IF EXISTS ${catalogo}.bronze.amazon_bestsellers;
DROP TABLE IF EXISTS ${catalogo}.bronze.country_reading;

# %%
dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/goodreads_books", True)
dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/amazon_bestsellers", True)
dbutils.fs.rm(f"abfss://bronze@{storageName}.dfs.core.windows.net/country_reading", True)

# %% [markdown]
# ### Eliminacion tablas Silver

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.silver.books_catalog_transformed;
DROP TABLE IF EXISTS ${catalogo}.silver.bestsellers_transformed;
DROP TABLE IF EXISTS ${catalogo}.silver.catalog_vs_bestsellers;
DROP TABLE IF EXISTS ${catalogo}.silver.country_reading_transformed;

# %%
dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/books_catalog_transformed", True)
dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/bestsellers_transformed", True)
dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/catalog_vs_bestsellers", True)
dbutils.fs.rm(f"abfss://silver@{storageName}.dfs.core.windows.net/country_reading_transformed", True)

# %% [markdown]
# ### Eliminacion tablas Golden

# %%
# %sql
DROP TABLE IF EXISTS ${catalogo}.golden.top_authors;
DROP TABLE IF EXISTS ${catalogo}.golden.top_books;
DROP TABLE IF EXISTS ${catalogo}.golden.genre_distribution;
DROP TABLE IF EXISTS ${catalogo}.golden.top_books_by_genre;
DROP TABLE IF EXISTS ${catalogo}.golden.country_reading;

# %%
dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/top_authors", True)
dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/top_books", True)
dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/genre_distribution", True)
dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/top_books_by_genre", True)
dbutils.fs.rm(f"abfss://golden@{storageName}.dfs.core.windows.net/country_reading", True)
